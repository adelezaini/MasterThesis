# %% [markdown]
# # Check spin-up / system in equilibrium

# %%
import numpy as np
import netCDF4
import pandas as pd
import xarray as xr
import glob #return all file paths that match a specific pattern
import matplotlib as mpl
import matplotlib.pyplot as plt

import sys; sys.path.append("..")
from dataset_manipulation import fix_cam_time

# %% [markdown]
# **NOTE**: If you then copy this to NIRD remember to change the path of the input files and the libraries

# %%
# Import 
raw_path = '../../../archive/' #Betzy: /cluster/home/adelez/nird/ #Nird: /nird/home/adelez/storage/
processed_path = '../../processed-data/postprocessing/'

# %%
# Have a look to the variables:

"""
casename = 'IDEAL-OFF_2000_sec_nudg_f19_f19'
fp = raw_path+casename+'/lnd/hist/'+casename+'.clm2.h0.2007-01.nc'
all_files = glob.glob(fp)
all_files.sort()
print("Files found")
ds0 = xr.open_mfdataset(all_files)
print("Dataset created")
ds0"""

# %%
def create_dataset(casename):
    fp = raw_path+casename+'/lnd/hist/'+casename+'.clm2.h0.*.nc'

    all_files = glob.glob(fp)
    all_files.sort()
    print("Files found")

    ds = xr.open_mfdataset(all_files)
    print("Dataset created")
    return ds

def print_timeseries(ds):
    for i in range(5,len(variables)):
        ds[variables[i]].mean('lon').mean('lat').plot()
        ds[variables[i]].mean('lon').mean('lat').chunk({'time': None}).rolling(time=12, center=True).mean().plot()
        plt.suptitle(variables[i]+' - '+ds[variables[i]].long_name)
        plt.show()

# %%
#evapotranspiration (ground evaporation + vegetation evaporation + vegetation transpiration)
#FGEV + QFLX_EVAP_VEG + FCTR
casename = 'IDEAL-ON_2000_f19_f19'
fp = raw_path+casename+'/lnd/hist/'+casename+'.clm2.h0.2007-01.nc'
ds = xr.open_dataset(fp)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (cft: 64, glc_nec: 10, hist_interval: 2, lat: 96, levdcmp: 25, levgrnd: 25, levlak: 10, levsoi: 20, lon: 144, ltype: 9, natpft: 15, nvegwcs: 4, time: 1)
# Coordinates:
#   * levgrnd                  (levgrnd) float64 0.01 0.04 0.09 ... 28.87 42.0
#   * levlak                   (levlak) float64 0.05 0.6 2.1 ... 25.6 34.33 44.77
#   * levdcmp                  (levdcmp) float64 0.01 0.04 0.09 ... 28.87 42.0
#   * time                     (time) datetime64[ns] 2007-02-01
#   * lon                      (lon) float64 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * lat                      (lat) float64 -90.0 -88.11 -86.21 ... 88.11 90.0
# Dimensions without coordinates: cft, glc_nec, hist_interval, levsoi, ltype, natpft, nvegwcs
# Data variables:
#     mcdate                   (time) int32 ...
#     mcsec                    (time) int32 ...
#     mdcur                    (time) int32 ...
#     mscur                    (time) int32 ...
#     nstep                    (time) int32 ...
#     time_bounds              (time, hist_interval) datetime64[ns] ...
#     date_written             (time) |S16 ...
#     time_written             (time) |S16 ...
#     area                     (lat, lon) float64 ...
#     landfrac                 (lat, lon) float64 ...
#     landmask                 (lat, lon) float64 ...
#     pftmask                  (lat, lon) float64 ...
#     nbedrock                 (lat, lon) float64 ...
#     ZSOI                     (levgrnd, lat, lon) float64 ...
#     DZSOI                    (levgrnd, lat, lon) float64 ...
#     WATSAT                   (levgrnd, lat, lon) float64 ...
#     SUCSAT                   (levgrnd, lat, lon) float64 ...
#     BSW                      (levgrnd, lat, lon) float64 ...
#     HKSAT                    (levgrnd, lat, lon) float64 ...
#     ZLAKE                    (levlak, lat, lon) float64 ...
#     DZLAKE                   (levlak, lat, lon) float64 ...
#     ACTUAL_IMMOB             (time, lat, lon) float64 ...
#     AGNPP                    (time, lat, lon) float64 ...
#     ALT                      (time, lat, lon) float64 ...
#     ALTMAX                   (time, lat, lon) float64 ...
#     AR                       (time, lat, lon) float64 ...
#     ATM_TOPO                 (time, lat, lon) float64 ...
#     BAF_CROP                 (time, lat, lon) float64 ...
#     BAF_PEATF                (time, lat, lon) float64 ...
#     BCDEP                    (time, lat, lon) float64 ...
#     BGNPP                    (time, lat, lon) float64 ...
#     BTRAN2                   (time, lat, lon) float64 ...
#     BTRANMN                  (time, lat, lon) float64 ...
#     CH4PROD                  (time, lat, lon) float64 ...
#     CH4_SURF_AERE_SAT        (time, lat, lon) float64 ...
#     CH4_SURF_AERE_UNSAT      (time, lat, lon) float64 ...
#     CH4_SURF_DIFF_SAT        (time, lat, lon) float64 ...
#     CH4_SURF_DIFF_UNSAT      (time, lat, lon) float64 ...
#     CH4_SURF_EBUL_SAT        (time, lat, lon) float64 ...
#     CH4_SURF_EBUL_UNSAT      (time, lat, lon) float64 ...
#     COL_FIRE_CLOSS           (time, lat, lon) float64 ...
#     COL_FIRE_NLOSS           (time, lat, lon) float64 ...
#     CONC_O2_SAT              (time, levsoi, lat, lon) float64 ...
#     CONC_O2_UNSAT            (time, levsoi, lat, lon) float64 ...
#     COST_NACTIVE             (time, lat, lon) float64 ...
#     COST_NFIX                (time, lat, lon) float64 ...
#     COST_NRETRANS            (time, lat, lon) float64 ...
#     CPHASE                   (time, lat, lon) float64 ...
#     CPOOL                    (time, lat, lon) float64 ...
#     CROPPROD1C               (time, lat, lon) float64 ...
#     CROPPROD1C_LOSS          (time, lat, lon) float64 ...
#     CROPPROD1N               (time, lat, lon) float64 ...
#     CROPPROD1N_LOSS          (time, lat, lon) float64 ...
#     CROPSEEDC_DEFICIT        (time, lat, lon) float64 ...
#     CWDC                     (time, lat, lon) float64 ...
#     CWDC_LOSS                (time, lat, lon) float64 ...
#     CWDC_vr                  (time, levsoi, lat, lon) float64 ...
#     CWDN                     (time, lat, lon) float64 ...
#     CWDN_vr                  (time, levdcmp, lat, lon) float64 ...
#     DEADCROOTC               (time, lat, lon) float64 ...
#     DEADCROOTN               (time, lat, lon) float64 ...
#     DEADSTEMC                (time, lat, lon) float64 ...
#     DEADSTEMN                (time, lat, lon) float64 ...
#     DENIT                    (time, lat, lon) float64 ...
#     DISPVEGC                 (time, lat, lon) float64 ...
#     DISPVEGN                 (time, lat, lon) float64 ...
#     DSL                      (time, lat, lon) float64 ...
#     DSTDEP                   (time, lat, lon) float64 ...
#     DSTFLXT                  (time, lat, lon) float64 ...
#     DWT_CONV_CFLUX           (time, lat, lon) float64 ...
#     DWT_CONV_CFLUX_DRIBBLED  (time, lat, lon) float64 ...
#     DWT_CONV_NFLUX           (time, lat, lon) float64 ...
#     DWT_CROPPROD1C_GAIN      (time, lat, lon) float64 ...
#     DWT_CROPPROD1N_GAIN      (time, lat, lon) float64 ...
#     DWT_SEEDN_TO_DEADSTEM    (time, lat, lon) float64 ...
#     DWT_SEEDN_TO_LEAF        (time, lat, lon) float64 ...
#     DWT_SLASH_CFLUX          (time, lat, lon) float64 ...
#     DWT_WOODPRODC_GAIN       (time, lat, lon) float64 ...
#     DWT_WOODPRODN_GAIN       (time, lat, lon) float64 ...
#     EFLXBUILD                (time, lat, lon) float64 ...
#     EFLX_DYNBAL              (time, lat, lon) float64 ...
#     EFLX_GRND_LAKE           (time, lat, lon) float64 ...
#     EFLX_LH_TOT              (time, lat, lon) float64 ...
#     EFLX_LH_TOT_R            (time, lat, lon) float64 ...
#     ELAI                     (time, lat, lon) float64 ...
#     ER                       (time, lat, lon) float64 ...
#     ERRH2O                   (time, lat, lon) float64 ...
#     ERRH2OSNO                (time, lat, lon) float64 ...
#     ERRSEB                   (time, lat, lon) float64 ...
#     ERRSOI                   (time, lat, lon) float64 ...
#     ERRSOL                   (time, lat, lon) float64 ...
#     ESAI                     (time, lat, lon) float64 ...
#     FAREA_BURNED             (time, lat, lon) float64 ...
#     FCEV                     (time, lat, lon) float64 ...
#     FCH4                     (time, lat, lon) float64 ...
#     FCH4TOCO2                (time, lat, lon) float64 ...
#     FCH4_DFSAT               (time, lat, lon) float64 ...
#     FCOV                     (time, lat, lon) float64 ...
#     FCTR                     (time, lat, lon) float64 ...
#     FFIX_TO_SMINN            (time, lat, lon) float64 ...
#     FGEV                     (time, lat, lon) float64 ...
#     FGR                      (time, lat, lon) float64 ...
#     FGR12                    (time, lat, lon) float64 ...
#     FH2OSFC                  (time, lat, lon) float64 ...
#     FINUNDATED               (time, lat, lon) float64 ...
#     FIRA                     (time, lat, lon) float64 ...
#     FIRA_R                   (time, lat, lon) float64 ...
#     FIRE                     (time, lat, lon) float64 ...
#     FIRE_R                   (time, lat, lon) float64 ...
#     FLDS                     (time, lat, lon) float64 ...
#     FPI                      (time, lat, lon) float64 ...
#     FPSN                     (time, lat, lon) float64 ...
#     FREE_RETRANSN_TO_NPOOL   (time, lat, lon) float64 ...
#     FROOTC                   (time, lat, lon) float64 ...
#     FROOTC_ALLOC             (time, lat, lon) float64 ...
#     FROOTC_LOSS              (time, lat, lon) float64 ...
#     FROOTN                   (time, lat, lon) float64 ...
#     FSA                      (time, lat, lon) float64 ...
#     FSAT                     (time, lat, lon) float64 ...
#     FSDS                     (time, lat, lon) float64 ...
#     FSDSND                   (time, lat, lon) float64 ...
#     FSDSNDLN                 (time, lat, lon) float64 ...
#     FSDSNI                   (time, lat, lon) float64 ...
#     FSDSVD                   (time, lat, lon) float64 ...
#     FSDSVDLN                 (time, lat, lon) float64 ...
#     FSDSVI                   (time, lat, lon) float64 ...
#     FSDSVILN                 (time, lat, lon) float64 ...
#     FSH                      (time, lat, lon) float64 ...
#     FSH_G                    (time, lat, lon) float64 ...
#     FSH_PRECIP_CONVERSION    (time, lat, lon) float64 ...
#     FSH_R                    (time, lat, lon) float64 ...
#     FSH_RUNOFF_ICE_TO_LIQ    (time, lat, lon) float64 ...
#     FSH_TO_COUPLER           (time, lat, lon) float64 ...
#     FSH_V                    (time, lat, lon) float64 ...
#     FSM                      (time, lat, lon) float64 ...
#     FSNO                     (time, lat, lon) float64 ...
#     FSNO_EFF                 (time, lat, lon) float64 ...
#     FSR                      (time, lat, lon) float64 ...
#     FSRND                    (time, lat, lon) float64 ...
#     FSRNDLN                  (time, lat, lon) float64 ...
#     FSRNI                    (time, lat, lon) float64 ...
#     FSRVD                    (time, lat, lon) float64 ...
#     FSRVDLN                  (time, lat, lon) float64 ...
#     FSRVI                    (time, lat, lon) float64 ...
#     FUELC                    (time, lat, lon) float64 ...
#     F_DENIT                  (time, lat, lon) float64 ...
#     F_N2O_DENIT              (time, lat, lon) float64 ...
#     F_N2O_NIT                (time, lat, lon) float64 ...
#     F_NIT                    (time, lat, lon) float64 ...
#     GPP                      (time, lat, lon) float64 ...
#     GR                       (time, lat, lon) float64 ...
#     GRAINC                   (time, lat, lon) float64 ...
#     GRAINC_TO_FOOD           (time, lat, lon) float64 ...
#     GRAINC_TO_SEED           (time, lat, lon) float64 ...
#     GRAINN                   (time, lat, lon) float64 ...
#     GROSS_NMIN               (time, lat, lon) float64 ...
#     GSSHA                    (time, lat, lon) float64 ...
#     GSSHALN                  (time, lat, lon) float64 ...
#     GSSUN                    (time, lat, lon) float64 ...
#     GSSUNLN                  (time, lat, lon) float64 ...
#     H2OCAN                   (time, lat, lon) float64 ...
#     H2OSFC                   (time, lat, lon) float64 ...
#     H2OSNO                   (time, lat, lon) float64 ...
#     H2OSNO_TOP               (time, lat, lon) float64 ...
#     H2OSOI                   (time, levsoi, lat, lon) float64 ...
#     HEAT_CONTENT1            (time, lat, lon) float64 ...
#     HEAT_FROM_AC             (time, lat, lon) float64 ...
#     HIA                      (time, lat, lon) float64 ...
#     HIA_R                    (time, lat, lon) float64 ...
#     HIA_U                    (time, lat, lon) float64 ...
#     HR                       (time, lat, lon) float64 ...
#     HR_vr                    (time, levsoi, lat, lon) float64 ...
#     HTOP                     (time, lat, lon) float64 ...
#     HUMIDEX                  (time, lat, lon) float64 ...
#     HUMIDEX_R                (time, lat, lon) float64 ...
#     HUMIDEX_U                (time, lat, lon) float64 ...
#     ICE_CONTENT1             (time, lat, lon) float64 ...
#     JMX25T                   (time, lat, lon) float64 ...
#     Jmx25Z                   (time, lat, lon) float64 ...
#     LAISHA                   (time, lat, lon) float64 ...
#     LAISUN                   (time, lat, lon) float64 ...
#     LAKEICEFRAC_SURF         (time, lat, lon) float64 ...
#     LAKEICETHICK             (time, lat, lon) float64 ...
#     LAND_USE_FLUX            (time, lat, lon) float64 ...
#     LEAFC                    (time, lat, lon) float64 ...
#     LEAFCN                   (time, lat, lon) float64 ...
#     LEAFC_ALLOC              (time, lat, lon) float64 ...
#     LEAFC_CHANGE             (time, lat, lon) float64 ...
#     LEAFC_LOSS               (time, lat, lon) float64 ...
#     LEAFC_TO_LITTER_FUN      (time, lat, lon) float64 ...
#     LEAFN                    (time, lat, lon) float64 ...
#     LEAFN_TO_LITTER          (time, lat, lon) float64 ...
#     LEAF_MR                  (time, lat, lon) float64 ...
#     LFC2                     (time, lat, lon) float64 ...
#     LIQCAN                   (time, lat, lon) float64 ...
#     LIQUID_CONTENT1          (time, lat, lon) float64 ...
#     LITFALL                  (time, lat, lon) float64 ...
#     LITR1C                   (time, lat, lon) float64 ...
#     LITR1C_vr                (time, levsoi, lat, lon) float64 ...
#     LITR1N                   (time, lat, lon) float64 ...
#     LITR1N_vr                (time, levdcmp, lat, lon) float64 ...
#     LITR2C                   (time, lat, lon) float64 ...
#     LITR2C_vr                (time, levsoi, lat, lon) float64 ...
#     LITR2N                   (time, lat, lon) float64 ...
#     LITR2N_vr                (time, levdcmp, lat, lon) float64 ...
#     LITR3C                   (time, lat, lon) float64 ...
#     LITR3C_vr                (time, levsoi, lat, lon) float64 ...
#     LITR3N                   (time, lat, lon) float64 ...
#     LITR3N_vr                (time, levdcmp, lat, lon) float64 ...
#     LITTERC_HR               (time, lat, lon) float64 ...
#     LITTERC_LOSS             (time, lat, lon) float64 ...
#     LIVECROOTC               (time, lat, lon) float64 ...
#     LIVECROOTN               (time, lat, lon) float64 ...
#     LIVESTEMC                (time, lat, lon) float64 ...
#     LIVESTEMN                (time, lat, lon) float64 ...
#     LNC                      (time, lat, lon) float64 ...
#     MEG_carene_3             (time, lat, lon) float64 ...
#     MEG_isoprene             (time, lat, lon) float64 ...
#     MEG_limonene             (time, lat, lon) float64 ...
#     MEG_myrcene              (time, lat, lon) float64 ...
#     MEG_ocimene_t_b          (time, lat, lon) float64 ...
#     MEG_pinene_a             (time, lat, lon) float64 ...
#     MEG_pinene_b             (time, lat, lon) float64 ...
#     MEG_sabinene             (time, lat, lon) float64 ...
#     MR                       (time, lat, lon) float64 ...
#     NACTIVE                  (time, lat, lon) float64 ...
#     NACTIVE_NH4              (time, lat, lon) float64 ...
#     NACTIVE_NO3              (time, lat, lon) float64 ...
#     NAM                      (time, lat, lon) float64 ...
#     NAM_NH4                  (time, lat, lon) float64 ...
#     NAM_NO3                  (time, lat, lon) float64 ...
#     NBP                      (time, lat, lon) float64 ...
#     NDEPLOY                  (time, lat, lon) float64 ...
#     NDEP_TO_SMINN            (time, lat, lon) float64 ...
#     NECM                     (time, lat, lon) float64 ...
#     NECM_NH4                 (time, lat, lon) float64 ...
#     NECM_NO3                 (time, lat, lon) float64 ...
#     NEE                      (time, lat, lon) float64 ...
#     NEM                      (time, lat, lon) float64 ...
#     NEP                      (time, lat, lon) float64 ...
#     NET_NMIN                 (time, lat, lon) float64 ...
#     NFERTILIZATION           (time, lat, lon) float64 ...
#     NFIRE                    (time, lat, lon) float64 ...
#     NFIX                     (time, lat, lon) float64 ...
#     NNONMYC                  (time, lat, lon) float64 ...
#     NNONMYC_NH4              (time, lat, lon) float64 ...
#     NNONMYC_NO3              (time, lat, lon) float64 ...
#     NPASSIVE                 (time, lat, lon) float64 ...
#     NPOOL                    (time, lat, lon) float64 ...
#     NPP                      (time, lat, lon) float64 ...
#     NPP_GROWTH               (time, lat, lon) float64 ...
#     NPP_NACTIVE              (time, lat, lon) float64 ...
#     NPP_NACTIVE_NH4          (time, lat, lon) float64 ...
#     NPP_NACTIVE_NO3          (time, lat, lon) float64 ...
#     NPP_NAM                  (time, lat, lon) float64 ...
#     NPP_NAM_NH4              (time, lat, lon) float64 ...
#     NPP_NAM_NO3              (time, lat, lon) float64 ...
#     NPP_NECM                 (time, lat, lon) float64 ...
#     NPP_NECM_NH4             (time, lat, lon) float64 ...
#     NPP_NECM_NO3             (time, lat, lon) float64 ...
#     NPP_NFIX                 (time, lat, lon) float64 ...
#     NPP_NNONMYC              (time, lat, lon) float64 ...
#     NPP_NNONMYC_NH4          (time, lat, lon) float64 ...
#     NPP_NNONMYC_NO3          (time, lat, lon) float64 ...
#     NPP_NRETRANS             (time, lat, lon) float64 ...
#     NPP_NUPTAKE              (time, lat, lon) float64 ...
#     NRETRANS                 (time, lat, lon) float64 ...
#     NRETRANS_REG             (time, lat, lon) float64 ...
#     NRETRANS_SEASON          (time, lat, lon) float64 ...
#     NRETRANS_STRESS          (time, lat, lon) float64 ...
#     NUPTAKE                  (time, lat, lon) float64 ...
#     NUPTAKE_NPP_FRACTION     (time, lat, lon) float64 ...
#     OCDEP                    (time, lat, lon) float64 ...
#     O_SCALAR                 (time, levsoi, lat, lon) float64 ...
#     PARVEGLN                 (time, lat, lon) float64 ...
#     PBOT                     (time, lat, lon) float64 ...
#     PCH4                     (time, lat, lon) float64 ...
#     PCO2                     (time, lat, lon) float64 ...
#     PCT_CFT                  (time, cft, lat, lon) float64 ...
#     PCT_GLC_MEC              (time, glc_nec, lat, lon) float64 ...
#     PCT_LANDUNIT             (time, ltype, lat, lon) float64 ...
#     PCT_NAT_PFT              (time, natpft, lat, lon) float64 ...
#     PFT_FIRE_CLOSS           (time, lat, lon) float64 ...
#     PFT_FIRE_NLOSS           (time, lat, lon) float64 ...
#     PLANT_NDEMAND            (time, lat, lon) float64 ...
#     POTENTIAL_IMMOB          (time, lat, lon) float64 ...
#     POT_F_DENIT              (time, lat, lon) float64 ...
#     POT_F_NIT                (time, lat, lon) float64 ...
#     PSNSHA                   (time, lat, lon) float64 ...
#     PSNSHADE_TO_CPOOL        (time, lat, lon) float64 ...
#     PSNSUN                   (time, lat, lon) float64 ...
#     PSNSUN_TO_CPOOL          (time, lat, lon) float64 ...
#     Q2M                      (time, lat, lon) float64 ...
#     QBOT                     (time, lat, lon) float64 ...
#     QCHARGE                  (time, lat, lon) float64 ...
#     QDRAI                    (time, lat, lon) float64 ...
#     QDRAI_PERCH              (time, lat, lon) float64 ...
#     QDRAI_XS                 (time, lat, lon) float64 ...
#     QDRIP                    (time, lat, lon) float64 ...
#     QFLOOD                   (time, lat, lon) float64 ...
#     QFLX_DEW_GRND            (time, lat, lon) float64 ...
#     QFLX_DEW_SNOW            (time, lat, lon) float64 ...
#     QFLX_EVAP_TOT            (time, lat, lon) float64 ...
#     QFLX_ICE_DYNBAL          (time, lat, lon) float64 ...
#     QFLX_LIQ_DYNBAL          (time, lat, lon) float64 ...
#     QFLX_SNOW_DRAIN          (time, lat, lon) float64 ...
#     QFLX_SNOW_DRAIN_ICE      (time, lat, lon) float64 ...
#     QFLX_SUB_SNOW            (time, lat, lon) float64 ...
#     QH2OSFC                  (time, lat, lon) float64 ...
#     QICE                     (time, lat, lon) float64 ...
#     QICE_FRZ                 (time, lat, lon) float64 ...
#     QICE_MELT                (time, lat, lon) float64 ...
#     QINFL                    (time, lat, lon) float64 ...
#     QINTR                    (time, lat, lon) float64 ...
#     QIRRIG                   (time, lat, lon) float64 ...
#     QOVER                    (time, lat, lon) float64 ...
#     QRGWL                    (time, lat, lon) float64 ...
#     QRUNOFF                  (time, lat, lon) float64 ...
#     QRUNOFF_ICE              (time, lat, lon) float64 ...
#     QRUNOFF_ICE_TO_COUPLER   (time, lat, lon) float64 ...
#     QRUNOFF_TO_COUPLER       (time, lat, lon) float64 ...
#     QSNOCPLIQ                (time, lat, lon) float64 ...
#     QSNOEVAP                 (time, lat, lon) float64 ...
#     QSNOFRZ                  (time, lat, lon) float64 ...
#     QSNOFRZ_ICE              (time, lat, lon) float64 ...
#     QSNOMELT                 (time, lat, lon) float64 ...
#     QSNOMELT_ICE             (time, lat, lon) float64 ...
#     QSNO_TEMPUNLOAD          (time, lat, lon) float64 ...
#     QSNO_WINDUNLOAD          (time, lat, lon) float64 ...
#     QSNWCPICE                (time, lat, lon) float64 ...
#     QSOIL                    (time, lat, lon) float64 ...
#     QSOIL_ICE                (time, lat, lon) float64 ...
#     QVEGE                    (time, lat, lon) float64 ...
#     QVEGT                    (time, lat, lon) float64 ...
#     RAIN                     (time, lat, lon) float64 ...
#     RAIN_FROM_ATM            (time, lat, lon) float64 ...
#     RETRANSN                 (time, lat, lon) float64 ...
#     RETRANSN_TO_NPOOL        (time, lat, lon) float64 ...
#     RH2M                     (time, lat, lon) float64 ...
#     RR                       (time, lat, lon) float64 ...
#     RSSHA                    (time, lat, lon) float64 ...
#     RSSUN                    (time, lat, lon) float64 ...
#     SABG                     (time, lat, lon) float64 ...
#     SABG_PEN                 (time, lat, lon) float64 ...
#     SABV                     (time, lat, lon) float64 ...
#     SEEDC                    (time, lat, lon) float64 ...
#     SEEDN                    (time, lat, lon) float64 ...
#     SLASH_HARVESTC           (time, lat, lon) float64 ...
#     SMINN                    (time, lat, lon) float64 ...
#     SMINN_TO_NPOOL           (time, lat, lon) float64 ...
#     SMINN_TO_PLANT           (time, lat, lon) float64 ...
#     SMINN_TO_PLANT_FUN       (time, lat, lon) float64 ...
#     SMINN_vr                 (time, levsoi, lat, lon) float64 ...
#     SMIN_NH4                 (time, lat, lon) float64 ...
#     SMIN_NH4_vr              (time, levsoi, lat, lon) float64 ...
#     SMIN_NO3                 (time, lat, lon) float64 ...
#     SMIN_NO3_LEACHED         (time, lat, lon) float64 ...
#     SMIN_NO3_RUNOFF          (time, lat, lon) float64 ...
#     SMIN_NO3_vr              (time, levsoi, lat, lon) float64 ...
#     SMP                      (time, levgrnd, lat, lon) float64 ...
#     SNOBCMCL                 (time, lat, lon) float64 ...
#     SNOBCMSL                 (time, lat, lon) float64 ...
#     SNOCAN                   (time, lat, lon) float64 ...
#     SNODSTMCL                (time, lat, lon) float64 ...
#     SNODSTMSL                (time, lat, lon) float64 ...
#     SNOFSRND                 (time, lat, lon) float64 ...
#     SNOFSRNI                 (time, lat, lon) float64 ...
#     SNOFSRVD                 (time, lat, lon) float64 ...
#     SNOFSRVI                 (time, lat, lon) float64 ...
#     SNOINTABS                (time, lat, lon) float64 ...
#     SNOOCMCL                 (time, lat, lon) float64 ...
#     SNOOCMSL                 (time, lat, lon) float64 ...
#     SNOTXMASS                (time, lat, lon) float64 ...
#     SNOUNLOAD                (time, lat, lon) float64 ...
#     SNOW                     (time, lat, lon) float64 ...
#     SNOWDP                   (time, lat, lon) float64 ...
#     SNOWICE                  (time, lat, lon) float64 ...
#     SNOWLIQ                  (time, lat, lon) float64 ...
#     SNOW_DEPTH               (time, lat, lon) float64 ...
#     SNOW_FROM_ATM            (time, lat, lon) float64 ...
#     SNOW_PERSISTENCE         (time, lat, lon) timedelta64[ns] ...
#     SNOW_SINKS               (time, lat, lon) float64 ...
#     SNOW_SOURCES             (time, lat, lon) float64 ...
#     SOIL1C                   (time, lat, lon) float64 ...
#     SOIL1C_vr                (time, levsoi, lat, lon) float64 ...
#     SOIL1N                   (time, lat, lon) float64 ...
#     SOIL1N_vr                (time, levdcmp, lat, lon) float64 ...
#     SOIL2C                   (time, lat, lon) float64 ...
#     SOIL2C_vr                (time, levsoi, lat, lon) float64 ...
#     SOIL2N                   (time, lat, lon) float64 ...
#     SOIL2N_vr                (time, levdcmp, lat, lon) float64 ...
#     SOIL3C                   (time, lat, lon) float64 ...
#     SOIL3C_vr                (time, levsoi, lat, lon) float64 ...
#     SOIL3N                   (time, lat, lon) float64 ...
#     SOIL3N_vr                (time, levdcmp, lat, lon) float64 ...
#     SOILC_CHANGE             (time, lat, lon) float64 ...
#     SOILC_HR                 (time, lat, lon) float64 ...
#     SOILICE                  (time, levsoi, lat, lon) float64 ...
#     SOILLIQ                  (time, levsoi, lat, lon) float64 ...
#     SOILRESIS                (time, lat, lon) float64 ...
#     SOILWATER_10CM           (time, lat, lon) float64 ...
#     SOMC_FIRE                (time, lat, lon) float64 ...
#     SOM_C_LEACHED            (time, lat, lon) float64 ...
#     SR                       (time, lat, lon) float64 ...
#     STORVEGC                 (time, lat, lon) float64 ...
#     STORVEGN                 (time, lat, lon) float64 ...
#     SUPPLEMENT_TO_SMINN      (time, lat, lon) float64 ...
#     SWBGT                    (time, lat, lon) float64 ...
#     SWBGT_R                  (time, lat, lon) float64 ...
#     SWBGT_U                  (time, lat, lon) float64 ...
#     TAUX                     (time, lat, lon) float64 ...
#     TAUY                     (time, lat, lon) float64 ...
#     TBOT                     (time, lat, lon) float64 ...
#     TBUILD                   (time, lat, lon) float64 ...
#     TG                       (time, lat, lon) float64 ...
#     TH2OSFC                  (time, lat, lon) float64 ...
#     THBOT                    (time, lat, lon) float64 ...
#     TKE1                     (time, lat, lon) float64 ...
#     TLAI                     (time, lat, lon) float64 ...
#     TLAKE                    (time, levlak, lat, lon) float64 ...
#     TOTCOLC                  (time, lat, lon) float64 ...
#     TOTCOLCH4                (time, lat, lon) float64 ...
#     TOTCOLN                  (time, lat, lon) float64 ...
#     TOTECOSYSC               (time, lat, lon) float64 ...
#     TOTECOSYSN               (time, lat, lon) float64 ...
#     TOTLITC                  (time, lat, lon) float64 ...
#     TOTLITC_1m               (time, lat, lon) float64 ...
#     TOTLITN                  (time, lat, lon) float64 ...
#     TOTLITN_1m               (time, lat, lon) float64 ...
#     TOTPFTC                  (time, lat, lon) float64 ...
#     TOTPFTN                  (time, lat, lon) float64 ...
#     TOTSOILICE               (time, lat, lon) float64 ...
#     TOTSOILLIQ               (time, lat, lon) float64 ...
#     TOTSOMC                  (time, lat, lon) float64 ...
#     TOTSOMC_1m               (time, lat, lon) float64 ...
#     TOTSOMN                  (time, lat, lon) float64 ...
#     TOTSOMN_1m               (time, lat, lon) float64 ...
#     TOTVEGC                  (time, lat, lon) float64 ...
#     TOTVEGN                  (time, lat, lon) float64 ...
#     TOT_WOODPRODC            (time, lat, lon) float64 ...
#     TOT_WOODPRODC_LOSS       (time, lat, lon) float64 ...
#     TOT_WOODPRODN            (time, lat, lon) float64 ...
#     TOT_WOODPRODN_LOSS       (time, lat, lon) float64 ...
#     TPU25T                   (time, lat, lon) float64 ...
#     TREFMNAV                 (time, lat, lon) float64 ...
#     TREFMXAV                 (time, lat, lon) float64 ...
#     TSA                      (time, lat, lon) float64 ...
#     TSAI                     (time, lat, lon) float64 ...
#     TSKIN                    (time, lat, lon) float64 ...
#     TSL                      (time, lat, lon) float64 ...
#     TSOI                     (time, levgrnd, lat, lon) float64 ...
#     TSOI_10CM                (time, lat, lon) float64 ...
#     TSOI_ICE                 (time, levgrnd, lat, lon) float64 ...
#     TV                       (time, lat, lon) float64 ...
#     TWS                      (time, lat, lon) float64 ...
#     T_SCALAR                 (time, levsoi, lat, lon) float64 ...
#     U10                      (time, lat, lon) float64 ...
#     U10_DUST                 (time, lat, lon) float64 ...
#     URBAN_AC                 (time, lat, lon) float64 ...
#     URBAN_HEAT               (time, lat, lon) float64 ...
#     VCMX25T                  (time, lat, lon) float64 ...
#     VEGWP                    (time, nvegwcs, lat, lon) float64 ...
#     VOLR                     (time, lat, lon) float64 ...
#     VOLRMCH                  (time, lat, lon) float64 ...
#     Vcmx25Z                  (time, lat, lon) float64 ...
#     WA                       (time, lat, lon) float64 ...
#     WASTEHEAT                (time, lat, lon) float64 ...
#     WBT                      (time, lat, lon) float64 ...
#     WBT_R                    (time, lat, lon) float64 ...
#     WBT_U                    (time, lat, lon) float64 ...
#     WIND                     (time, lat, lon) float64 ...
#     WOODC                    (time, lat, lon) float64 ...
#     WOODC_ALLOC              (time, lat, lon) float64 ...
#     WOODC_LOSS               (time, lat, lon) float64 ...
#     WOOD_HARVESTC            (time, lat, lon) float64 ...
#     WOOD_HARVESTN            (time, lat, lon) float64 ...
#     WTGQ                     (time, lat, lon) float64 ...
#     W_SCALAR                 (time, levsoi, lat, lon) float64 ...
#     XSMRPOOL                 (time, lat, lon) float64 ...
#     XSMRPOOL_RECOVER         (time, lat, lon) float64 ...
#     ZBOT                     (time, lat, lon) float64 ...
#     ZWT                      (time, lat, lon) float64 ...
#     ZWT_CH4_UNSAT            (time, lat, lon) float64 ...
#     ZWT_PERCH                (time, lat, lon) float64 ...
# Attributes:
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   created on 02/13/23 01:28:27
#     source:                                    Community Land Model CLM4.0
#     hostname:                                  betzy
#     username:                                  adelez
#     version:                                   release-noresm2.0.2-272-ge7cfcac
#     revision_id:                               $Id: histFileMod.F90 42903 201...
#     case_title:                                UNSET
#     case_id:                                   IDEAL-ON_2000_f19_f19
#     Surface_dataset:                           surfdata_1.9x2.5_hist_78pfts_C...
#     Initial_conditions_dataset:                finidat_interp_dest.nc
#     PFT_physiological_constants_dataset:       clm5_params.c171117.nc
#     ltype_vegetated_or_bare_soil:              1
#     ltype_crop:                                2
#     ltype_UNUSED:                              3
#     ltype_landice_multiple_elevation_classes:  4
#     ltype_deep_lake:                           5
#     ltype_wetland:                             6
#     ltype_urban_tbd:                           7
#     ltype_urban_hd:                            8
#     ltype_urban_md:                            9
#     ctype_vegetated_or_bare_soil:              1
#     ctype_crop:                                2
#     ctype_crop_noncompete:                     2*100+m, m=cft_lb,cft_ub
#     ctype_landice:                             3
#     ctype_landice_multiple_elevation_classes:  4*100+m, m=1,glcnec
#     ctype_deep_lake:                           5
#     ctype_wetland:                             6
#     ctype_urban_roof:                          71
#     ctype_urban_sunwall:                       72
#     ctype_urban_shadewall:                     73
#     ctype_urban_impervious_road:               74
#     ctype_urban_pervious_road:                 75
#     cft_c3_crop:                               1
#     cft_c3_irrigated:                          2
#     cft_temperate_corn:                        3
#     cft_irrigated_temperate_corn:              4
#     cft_spring_wheat:                          5
#     cft_irrigated_spring_wheat:                6
#     cft_winter_wheat:                          7
#     cft_irrigated_winter_wheat:                8
#     cft_temperate_soybean:                     9
#     cft_irrigated_temperate_soybean:           10
#     cft_barley:                                11
#     cft_irrigated_barley:                      12
#     cft_winter_barley:                         13
#     cft_irrigated_winter_barley:               14
#     cft_rye:                                   15
#     cft_irrigated_rye:                         16
#     cft_winter_rye:                            17
#     cft_irrigated_winter_rye:                  18
#     cft_cassava:                               19
#     cft_irrigated_cassava:                     20
#     cft_citrus:                                21
#     cft_irrigated_citrus:                      22
#     cft_cocoa:                                 23
#     cft_irrigated_cocoa:                       24
#     cft_coffee:                                25
#     cft_irrigated_coffee:                      26
#     cft_cotton:                                27
#     cft_irrigated_cotton:                      28
#     cft_datepalm:                              29
#     cft_irrigated_datepalm:                    30
#     cft_foddergrass:                           31
#     cft_irrigated_foddergrass:                 32
#     cft_grapes:                                33
#     cft_irrigated_grapes:                      34
#     cft_groundnuts:                            35
#     cft_irrigated_groundnuts:                  36
#     cft_millet:                                37
#     cft_irrigated_millet:                      38
#     cft_oilpalm:                               39
#     cft_irrigated_oilpalm:                     40
#     cft_potatoes:                              41
#     cft_irrigated_potatoes:                    42
#     cft_pulses:                                43
#     cft_irrigated_pulses:                      44
#     cft_rapeseed:                              45
#     cft_irrigated_rapeseed:                    46
#     cft_rice:                                  47
#     cft_irrigated_rice:                        48
#     cft_sorghum:                               49
#     cft_irrigated_sorghum:                     50
#     cft_sugarbeet:                             51
#     cft_irrigated_sugarbeet:                   52
#     cft_sugarcane:                             53
#     cft_irrigated_sugarcane:                   54
#     cft_sunflower:                             55
#     cft_irrigated_sunflower:                   56
#     cft_miscanthus:                            57
#     cft_irrigated_miscanthus:                  58
#     cft_switchgrass:                           59
#     cft_irrigated_switchgrass:                 60
#     cft_tropical_corn:                         61
#     cft_irrigated_tropical_corn:               62
#     cft_tropical_soybean:                      63
#     cft_irrigated_tropical_soybean:            64
#     time_period_freq:                          month_1

# %%
# From Hui's advice
variables = ['area', 'landfrac', 'landmask', 'pftmask', 'PCT_LANDUNIT',
             'MEG_isoprene', 'MEG_limonene', 'MEG_myrcene', 'MEG_ocimene_t_b', 'MEG_pinene_a', 'MEG_pinene_b', 
             'MEG_sabinene', 'PCT_NAT_PFT', 
             'GPP', 'NPP', 'NEE', 'NEP',
             'STORVEGN', 'TOTPFTN', 'TOTVEGN',
             'TOTCOLC', 'TOTECOSYSC', 'TOTPFTC', 'TOTVEGC', 'STORVEGC',
            'TLAI']


# IDEAL-ON_2000_sec_nudg_f19_f19


ds1 = create_dataset(casename = 'IDEAL-ON_2000_f19_f19')
print_timeseries(ds1)
# Out:
# Files found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c272dde876c9> in <module>
#      11 # IDEAL-ON_2000_sec_nudg_f19_f19
#      12
# ---> 13 ds1 = create_dataset(casename = 'IDEAL-ON_2000_f19_f19')
#      14 print_timeseries(ds1)
#
# <ipython-input-3-7ac10fb43435> in create_dataset(casename)
#       6     print("Files found")
#       7
# ----> 8     ds = xr.open_mfdataset(all_files)
#       9     print("Dataset created")
#      10     return ds
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, autoclose, parallel, join, attrs_file, **kwargs)
#     946         getattr_ = getattr
#     947
# --> 948     datasets = [open_(p, **open_kwargs) for p in paths]
#     949     file_objs = [getattr_(ds, "_file_obj") for ds in datasets]
#     950     if preprocess is not None:
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/api.py in <listcomp>(.0)
#     946         getattr_ = getattr
#     947
# --> 948     datasets = [open_(p, **open_kwargs) for p in paths]
#     949     file_objs = [getattr_(ds, "_file_obj") for ds in datasets]
#     950     if preprocess is not None:
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     573
#     574     with close_on_error(store):
# --> 575         ds = maybe_decode_store(store, chunks)
#     576
#     577     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/api.py in maybe_decode_store(store, chunks)
#     477             drop_variables=drop_variables,
#     478             use_cftime=use_cftime,
# --> 479             decode_timedelta=decode_timedelta,
#     480         )
#     481
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     580         encoding = obj.encoding
#     581     elif isinstance(obj, AbstractDataStore):
# --> 582         vars, attrs = obj.load()
#     583         extra_coords = set()
#     584         file_obj = obj
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/common.py in load(self)
#     110         """
#     111         variables = FrozenDict(
# --> 112             (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     113         )
#     114         attributes = FrozenDict(self.get_attrs())
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/netCDF4_.py in get_variables(self)
#     404     def get_variables(self):
#     405         dsvars = FrozenDict(
# --> 406             (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     407         )
#     408         return dsvars
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/core/utils.py in FrozenDict(*args, **kwargs)
#     440
#     441 def FrozenDict(*args, **kwargs) -> Frozen:
# --> 442     return Frozen(dict(*args, **kwargs))
#     443
#     444
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/netCDF4_.py in <genexpr>(.0)
#     404     def get_variables(self):
#     405         dsvars = FrozenDict(
# --> 406             (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     407         )
#     408         return dsvars
#
# ~/pyenv/lib64/python3.6/site-packages/xarray/backends/netCDF4_.py in open_store_variable(self, name, var)
#     397         # save source so __repr__ can detect if it's local or not
#     398         encoding["source"] = self._filename
# --> 399         encoding["original_shape"] = var.shape
#     400         encoding["dtype"] = var.dtype
#     401
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.shape.__get__()
#
# ~/pyenv/lib64/python3.6/site-packages/netCDF4/utils.py in _find_dim(grp, dimname)
#      32     return [A[i] for i in sorted(range(len(A)), key=B.__getitem__)]
#      33
# ---> 34 def _find_dim(grp, dimname):
#      35     # find Dimension instance given group and name.
#      36     # look in current group, and parents.
#
# KeyboardInterrupt:

# %%
#evapotranspiration (ground evaporation + vegetation evaporation + vegetation transpiration)
ds1

# %%
# REAL-ON_2000_sec_nudg_f19_f19

ds3 = create_dataset(casename = 'REAL-ON_2000_sec_nudg_f19_f19')
print_timeseries(ds3)
# Out:
# Files found
# Dataset created
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
# From Hui's advice
variables = ['area', 'landfrac', 'landmask', 'pftmask', 'PCT_LANDUNIT',
             #'MEG_isoprene', 'MEG_limonene', 'MEG_myrcene', 'MEG_ocimene_t_b', 'MEG_pinene_a', 'MEG_pinene_b', 'MEG_sabinene', 
             'PCT_NAT_PFT', 
             'GPP', 'NPP', 'NEE', 'NEP',
             'STORVEGN', 'TOTPFTN', 'TOTVEGN',
             'TOTCOLC', 'TOTECOSYSC', 'TOTPFTC', 'TOTVEGC', 'STORVEGC',
            'TLAI']

# IDEAL-OFF_2000_sec_nudg_f19_f19

ds2 = create_dataset(casename = 'IDEAL-OFF_2000_sec_nudg_f19_f19')
print_timeseries(ds2)
# Out:
# Files found
# Dataset created
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
# REAL-OFF_2000_sec_nudg_f19_f19

ds4 = create_dataset(casename = 'REAL-OFF_2000_sec_nudg_f19_f19')
print_timeseries(ds4)
# Out:
# Files found
# Dataset created
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /cluster/home/adelez/pyenv/lib64/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
